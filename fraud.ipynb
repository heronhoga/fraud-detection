# %% [markdown]
# import libraries

# %%
import pandas as pd

# %% [markdown]
# read csv

# %%
df = pd.read_csv('financial_fraud_detection_dataset.csv')
df.head()
# Out:
#   transaction_id                   timestamp sender_account receiver_account  \
# 0        T100000  2023-08-22T09:22:43.516168      ACC877572        ACC388389
# 1        T100001  2023-08-04T01:58:02.606711      ACC895667        ACC944962
# 2        T100002  2023-05-12T11:39:33.742963      ACC733052        ACC377370
# 3        T100003  2023-10-10T06:04:43.195112      ACC996865        ACC344098
# 4        T100004  2023-09-24T08:09:02.700162      ACC584714        ACC497887
#
#     amount transaction_type merchant_category location device_used  is_fraud  \
# 0   343.78       withdrawal         utilities    Tokyo      mobile     False
# 1   419.65       withdrawal            online  Toronto         atm     False
# 2  2773.86          deposit             other   London         pos     False
# 3  1666.22          deposit            online   Sydney         pos     False
# 4    24.43         transfer         utilities  Toronto      mobile     False
#
#   fraud_type  time_since_last_transaction  spending_deviation_score  \
# 0        NaN                          NaN                     -0.21
# 1        NaN                          NaN                     -0.14
# 2        NaN                          NaN                     -1.78
# 3        NaN                          NaN                     -0.60
# 4        NaN                          NaN                      0.79
#
#    velocity_score  geo_anomaly_score payment_channel       ip_address  \
# 0               3               0.22            card   13.101.214.112
# 1               7               0.96             ACH    172.52.47.194
# 2              20               0.89            card     185.98.35.23
# 3               6               0.37   wire_transfer    107.136.36.87
# 4              13               0.27             ACH  108.161.108.255
#
#   device_hash
# 0    D8536477
# 1    D2622631
# 2    D4823498
# 3    D9961380
# 4    D7637601

# %% [markdown]
# true fraud

# %%
fraud_df = df.loc[df['is_fraud'] == True]
fraud_types = df['fraud_type'].dropna().unique()
print(fraud_types)
# Out:
# ['card_not_present']

# %% [markdown]
# remove several columns

# %%
df = df.drop(columns=[
    'transaction_id',
    'sender_account',
    'receiver_account',
    'ip_address',
    'device_hash',
    'fraud_type'
])
df.head()
# Out:
#                     timestamp   amount transaction_type merchant_category  \
# 0  2023-08-22T09:22:43.516168   343.78       withdrawal         utilities
# 1  2023-08-04T01:58:02.606711   419.65       withdrawal            online
# 2  2023-05-12T11:39:33.742963  2773.86          deposit             other
# 3  2023-10-10T06:04:43.195112  1666.22          deposit            online
# 4  2023-09-24T08:09:02.700162    24.43         transfer         utilities
#
#   location device_used  is_fraud  time_since_last_transaction  \
# 0    Tokyo      mobile     False                          NaN
# 1  Toronto         atm     False                          NaN
# 2   London         pos     False                          NaN
# 3   Sydney         pos     False                          NaN
# 4  Toronto      mobile     False                          NaN
#
#    spending_deviation_score  velocity_score  geo_anomaly_score payment_channel
# 0                     -0.21               3               0.22            card
# 1                     -0.14               7               0.96             ACH
# 2                     -1.78              20               0.89            card
# 3                     -0.60               6               0.37   wire_transfer
# 4                      0.79              13               0.27             ACH

# %% [markdown]
# split the timestamp

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'], format='ISO8601', errors='coerce')

df['hour'] = df['timestamp'].dt.hour
df['day_of_week'] = df['timestamp'].dt.dayofweek
df['is_weekend'] = df['day_of_week'].isin([5, 6]).astype(int)

df = df.drop(columns=['timestamp'])

df.head()
# Out:
#     amount transaction_type merchant_category location device_used  is_fraud  \
# 0   343.78       withdrawal         utilities    Tokyo      mobile     False
# 1   419.65       withdrawal            online  Toronto         atm     False
# 2  2773.86          deposit             other   London         pos     False
# 3  1666.22          deposit            online   Sydney         pos     False
# 4    24.43         transfer         utilities  Toronto      mobile     False
#
#    time_since_last_transaction  spending_deviation_score  velocity_score  \
# 0                          NaN                     -0.21               3
# 1                          NaN                     -0.14               7
# 2                          NaN                     -1.78              20
# 3                          NaN                     -0.60               6
# 4                          NaN                      0.79              13
#
#    geo_anomaly_score payment_channel  hour  day_of_week  is_weekend
# 0               0.22            card     9            1           0
# 1               0.96             ACH     1            4           0
# 2               0.89            card    11            4           0
# 3               0.37   wire_transfer     6            1           0
# 4               0.27             ACH     8            6           1

# %% [markdown]
# check correlation

# %%
df.corr(numeric_only=True)
# Out:
#                                amount  is_fraud  time_since_last_transaction  \
# amount                       1.000000 -0.000167                     0.000316
# is_fraud                    -0.000167  1.000000                     0.000014
# time_since_last_transaction  0.000316  0.000014                     1.000000
# spending_deviation_score     0.000799  0.000201                     0.000202
# velocity_score              -0.000811  0.000370                     0.000088
# geo_anomaly_score            0.000176  0.000311                    -0.000031
# hour                        -0.000621 -0.000782                    -0.000188
# day_of_week                 -0.000394  0.000668                     0.007570
# is_weekend                  -0.000015  0.000734                     0.006026
#
#                              spending_deviation_score  velocity_score  \
# amount                                   7.986702e-04       -0.000811
# is_fraud                                 2.005477e-04        0.000370
# time_since_last_transaction              2.017022e-04        0.000088
# spending_deviation_score                 1.000000e+00       -0.000155
# velocity_score                          -1.552447e-04        1.000000
# geo_anomaly_score                        4.723374e-04        0.000340
# hour                                    -3.377701e-07        0.000404
# day_of_week                             -7.801599e-04        0.000941
# is_weekend                              -7.090146e-04        0.000668
#
#                              geo_anomaly_score          hour  day_of_week  \
# amount                                0.000176 -6.209222e-04    -0.000394
# is_fraud                              0.000311 -7.818012e-04     0.000668
# time_since_last_transaction          -0.000031 -1.883589e-04     0.007570
# spending_deviation_score              0.000472 -3.377701e-07    -0.000780
# velocity_score                        0.000340  4.035007e-04     0.000941
# geo_anomaly_score                     1.000000 -5.381750e-04    -0.000171
# hour                                 -0.000538  1.000000e+00     0.002046
# day_of_week                          -0.000171  2.046489e-03     1.000000
# is_weekend                           -0.000350  1.956188e-03     0.791170
#
#                              is_weekend
# amount                        -0.000015
# is_fraud                       0.000734
# time_since_last_transaction    0.006026
# spending_deviation_score      -0.000709
# velocity_score                 0.000668
# geo_anomaly_score             -0.000350
# hour                           0.001956
# day_of_week                    0.791170
# is_weekend                     1.000000
